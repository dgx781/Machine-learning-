# %% [markdown]
# <a href="https://colab.research.google.com/github/dgx781/dgx781/blob/DataScience-Ocean/Simple_ANN_classification_with_and_without_Dropout_in_deep_learnning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/mydrive')
# Out:
# Mounted at /content/mydrive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
import warnings
warnings.filterwarnings(action='ignore')

# %%
df= pd.read_csv("/content/mydrive/MyDrive/Dataset/sonar_dataset.csv")
df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# ...

# %%
df.sample(5)
# Out:
#     0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 60  0.0135  0.0045  0.0051  0.0289  0.0561  0.0929  0.1031  0.0883  0.1596
# 90  0.0253  0.0808  0.0507  0.0244  0.1724  0.3823  0.3729  0.3583  0.3429
# 70  0.0036  0.0078  0.0092  0.0387  0.0530  0.1197  0.1243  0.1026  0.1239
# 29  0.0240  0.0218  0.0324  0.0569  0.0330  0.0513  0.0897  0.0713  0.0569
# 79  0.0229  0.0369  0.0040  0.0375  0.0455  0.1452  0.2211  0.1188  0.0750
#
#     0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 60  0.1908  ...  0.0037  0.0084  0.0102  0.0096  0.0024  0.0037  0.0028
# 90  0.2197  ...  0.0178  0.0073  0.0079  0.0038  0.0116  0.0033  0.0039
# 70  0.0888  ...  0.0119  0.0055  0.0035  0.0036  0.0004  0.0018  0.0049
# 29  0.0389  ...  0.0162  0.0146  0.0093  0.0112  0.0094  0.0054  0.0019
# 79  0.1631  ...  0.0064  0.0022  0.0122  0.0151  0.0056  0.0026  0.0029
#
#     0.0090  0.0032  R
# 60  0.0030  0.0030  R
# 90  0.0081  0.0053  R
# ...

# %%
df.shape
# Out:
# (207, 61)

# %%
df.isna().sum()
# Out:
# 0.0200    0
# 0.0371    0
# 0.0428    0
# 0.0207    0
# 0.0954    0
#          ..
# 0.0180    0
# 0.0084    0
# 0.0090    0
# 0.0032    0
# R         0
# Length: 61, dtype: int64

# %%
df.columns
# Out:
# Index(['0.0200', '0.0371', '0.0428', '0.0207', '0.0954', '0.0986', '0.1539',
#        '0.1601', '0.3109', '0.2111', '0.1609', '0.1582', '0.2238', '0.0645',
#        '0.0660', '0.2273', '0.3100', '0.2999', '0.5078', '0.4797', '0.5783',
#        '0.5071', '0.4328', '0.5550', '0.6711', '0.6415', '0.7104', '0.8080',
#        '0.6791', '0.3857', '0.1307', '0.2604', '0.5121', '0.7547', '0.8537',
#        '0.8507', '0.6692', '0.6097', '0.4943', '0.2744', '0.0510', '0.2834',
#        '0.2825', '0.4256', '0.2641', '0.1386', '0.1051', '0.1343', '0.0383',
#        '0.0324', '0.0232', '0.0027', '0.0065', '0.0159', '0.0072', '0.0167',
#        '0.0180', '0.0084', '0.0090', '0.0032', 'R'],
#       dtype='object')

# %%
df['R'].value_counts()
# Out:
# M    111
# R     96
# Name: R, dtype: int64

# %%
x= df.drop('R', axis=1)
y= df["R"]
x.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0232  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  \
# 0  0.2872  ...  0.0125  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140
# 1  0.6194  ...  0.0033  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316
# 2  0.1264  ...  0.0241  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050
# 3  0.4459  ...  0.0156  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072
# 4  0.3039  ...  0.0104  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057
#
#    0.0084  0.0090  0.0032
# 0  0.0049  0.0052  0.0044
# 1  0.0164  0.0095  0.0078
# ...

# %%
y
# Out:
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 202    M
# 203    M
# 204    M
# 205    M
# 206    M
# Name: R, Length: 207, dtype: object

# %%
y= pd.get_dummies(y, drop_first=True)
y.sample(5)
# Out:
#      R
# 19   1
# 18   1
# 123  0
# 34   1
# 25   1

# %%
y.value_counts()
# Out:
# R
# 0    111
# 1     96
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.25, random_state=10)

# %%
x_train.shape, x_test.shape
# Out:
# ((155, 60), (52, 60))

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from keras.api._v2.keras import activations
model= keras.Sequential([
    keras.layers.Dense(60, input_dim=60, activation='relu'),
     keras.layers.Dense(60, activation='relu'),
      keras.layers.Dense(60, activation='relu'),
       keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=100, batch_size=8)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 3ms/step - loss: 0.6809 - accuracy: 0.5097
# Epoch 2/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6459 - accuracy: 0.6065
# Epoch 3/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6091 - accuracy: 0.6903
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5700 - accuracy: 0.7226
# Epoch 5/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.5221 - accuracy: 0.7161
# Epoch 6/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4913 - accuracy: 0.7613
# Epoch 7/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.4430 - accuracy: 0.7806
# Epoch 8/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.4019 - accuracy: 0.8194
# Epoch 9/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.3997 - accuracy: 0.8194
# Epoch 10/100
# ...

# %%
model.evaluate(x_test, y_test)
# Out:
# 2/2 [==============================] - 0s 7ms/step - loss: 0.7706 - accuracy: 0.8846
# [0.7706006765365601, 0.8846153616905212]

# %%
y_pred= model.predict(x_test).reshape(-1)
# Out:
# 2/2 [==============================] - 0s 6ms/step

# %%
print(y_pred[:10])
y_pred= np.round(y_pred)
print(y_pred[:10])
# Out:
# [1.0000000e+00 9.9999940e-01 9.9999982e-01 7.2031173e-05 1.0000000e+00
#  9.9999952e-01 8.9403379e-01 1.3104286e-03 7.2873656e-05 9.8631442e-01]
# [1. 1. 1. 0. 1. 1. 1. 0. 0. 1.]

# %%
y_test[:10]
# Out:
#      R
# 58   1
# 63   1
# 35   1
# 19   1
# 59   1
# 56   1
# 83   1
# 105  0
# 121  0
# 76   1

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      0.81      0.90        32
#          1.0       0.77      1.00      0.87        20
#
#     accuracy                           0.88        52
#    macro avg       0.88      0.91      0.88        52
# weighted avg       0.91      0.88      0.89        52

# %%
from keras.api._v2.keras import activations
model= keras.Sequential([
    keras.layers.Dense(60, input_dim=60, activation='relu'),
    keras.layers.Dropout(0.50),
     keras.layers.Dense(60, activation='relu'),
    keras.layers.Dropout(0.50),
      keras.layers.Dense(60, activation='relu'),
    keras.layers.Dropout(0.50),
       keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=100, batch_size=8)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 1s 3ms/step - loss: 0.6965 - accuracy: 0.5161
# Epoch 2/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6781 - accuracy: 0.5290
# Epoch 3/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6967 - accuracy: 0.5871
# Epoch 4/100
# 20/20 [==============================] - 0s 2ms/step - loss: 0.6804 - accuracy: 0.5290
# Epoch 5/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6866 - accuracy: 0.6129
# Epoch 6/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6691 - accuracy: 0.6000
# Epoch 7/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6863 - accuracy: 0.5742
# Epoch 8/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6826 - accuracy: 0.5677
# Epoch 9/100
# 20/20 [==============================] - 0s 3ms/step - loss: 0.6657 - accuracy: 0.5613
# Epoch 10/100
# ...

# %%
model.evaluate(x_test, y_test)
# Out:
# 2/2 [==============================] - 0s 14ms/step - loss: 0.4839 - accuracy: 0.8077
# [0.48394495248794556, 0.807692289352417]

# %%
y_pred= model.predict(x_test).reshape(-1)
# Out:
# 2/2 [==============================] - 0s 7ms/step

# %%
print(y_pred[:10])
y_pred= np.round(y_pred)
print(y_pred[:10])
# Out:
# [0.9993933  0.9998293  0.9982396  0.09416548 0.99840504 0.9987925
#  0.17007715 0.24220708 0.0790593  0.6593395 ]
# [1. 1. 1. 0. 1. 1. 0. 0. 0. 1.]

# %%
y_test[:10]
# Out:
#      R
# 58   1
# 63   1
# 35   1
# 19   1
# 59   1
# 56   1
# 83   1
# 105  0
# 121  0
# 76   1

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.92      0.75      0.83        32
#          1.0       0.69      0.90      0.78        20
#
#     accuracy                           0.81        52
#    macro avg       0.81      0.82      0.81        52
# weighted avg       0.83      0.81      0.81        52
