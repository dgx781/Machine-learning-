# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings(action='ignore')

# %%
df= pd.read_csv(r"C:\Users\DIBYOJIT\Downloads\titanic_train.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
gender= {'male':1,
        'female':0}

# %%
df['Sex']= df['Sex'].map(gender)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
from sklearn.impute import SimpleImputer
impute= SimpleImputer(missing_values=np.nan, strategy='median')
df['Age']= impute.fit_transform(df['Age'].values.reshape(-1,1))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin Embarked
# 0         A/5 21171   7.2500   NaN        S
# 1          PC 17599  71.2833   C85        C
# 2  STON/O2. 3101282   7.9250   NaN        S
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    int64
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(6), object(4)
# memory usage: 83.7+ KB

# %%
df[df['Cabin'].notnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name  Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 6                              McCarthy, Mr. Timothy J    1  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut    0   4.0      1
# 11                            Bonnell, Miss. Elizabeth    0  58.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
from sklearn.impute import SimpleImputer
impute= SimpleImputer(missing_values=np.nan, strategy='most_frequent')
df['Cabin']= impute.fit_transform(df['Cabin'].values.reshape(-1,1))

# %%
df['Cabin'].isnull().sum()
# Out:
# 0

# %%
df['Ticket']=pd.to_numeric(df['Ticket'], errors='coerce')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#      Ticket     Fare    Cabin Embarked
# 0       NaN   7.2500  B96 B98        S
# 1       NaN  71.2833      C85        C
# 2       NaN   7.9250  B96 B98        S
# 3  113803.0  53.1000     C123        S
# 4  373450.0   8.0500  B96 B98        S

# %%
df['Ticket'].isnull().sum()
# Out:
# 230

# %%
impute= SimpleImputer(missing_values=np.nan, strategy='median')
df['Ticket']= impute.fit_transform(df['Ticket'].values.reshape(-1,1))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#      Ticket     Fare    Cabin Embarked
# 0  236171.0   7.2500  B96 B98        S
# 1  236171.0  71.2833      C85        C
# 2  236171.0   7.9250  B96 B98        S
# 3  113803.0  53.1000     C123        S
# 4  373450.0   8.0500  B96 B98        S

# %%
df['Cabin'].value_counts().to_dict()
# Out:
# {'B96 B98': 691,
#  'G6': 4,
#  'C23 C25 C27': 4,
#  'C22 C26': 3,
#  'F33': 3,
#  'D': 3,
#  'F2': 3,
#  'E101': 3,
#  'E24': 2,
#  'B49': 2,
#  'E8': 2,
#  'C125': 2,
#  'B20': 2,
#  'B77': 2,
#  'D35': 2,
#  'C78': 2,
#  'C93': 2,
#  'C65': 2,
#  'B57 B59 B63 B66': 2,
#  'B5': 2,
#  'E121': 2,
#  'B51 B53 B55': 2,
#  'B18': 2,
#  'C124': 2,
#  'C126': 2,
#  'B35': 2,
#  'E44': 2,
#  'C92': 2,
#  'C68': 2,
#  'D20': 2,
#  'B22': 2,
#  'E25': 2,
#  'D36': 2,
#  'E67': 2,
#  'D17': 2,
#  'D33': 2,
#  'C123': 2,
#  'C52': 2,
#  'B28': 2,
#  'F4': 2,
#  'C83': 2,
#  'E33': 2,
#  'B58 B60': 2,
#  'C2': 2,
#  'F G73': 2,
#  'D26': 2,
#  'D28': 1,
#  'D19': 1,
#  'A23': 1,
#  'D50': 1,
#  'D9': 1,
#  'A20': 1,
#  'D11': 1,
#  'B41': 1,
#  'A26': 1,
#  'E17': 1,
#  'E68': 1,
#  'A10': 1,
#  'A24': 1,
#  'C101': 1,
#  'A16': 1,
#  'C70': 1,
#  'C86': 1,
#  'C50': 1,
#  'B42': 1,
#  'B39': 1,
#  'B50': 1,
#  'B71': 1,
#  'D48': 1,
#  'B82 B84': 1,
#  'D30': 1,
#  'C46': 1,
#  'E77': 1,
# ...

# %%
df['Cabin']= df['Cabin'].map(df['Cabin'].value_counts().to_dict())
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#      Ticket     Fare  Cabin Embarked
# 0  236171.0   7.2500    691        S
# 1  236171.0  71.2833      1        C
# 2  236171.0   7.9250    691        S
# 3  113803.0  53.1000      2        S
# 4  373450.0   8.0500    691        S

# %%
df.drop(['Name'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch    Ticket     Fare  \
# 0            1         0       3    1  22.0      1      0  236171.0   7.2500
# 1            2         1       1    0  38.0      1      0  236171.0  71.2833
# 2            3         1       3    0  26.0      0      0  236171.0   7.9250
# 3            4         1       1    0  35.0      1      0  113803.0  53.1000
# 4            5         0       3    1  35.0      0      0  373450.0   8.0500
#
#    Cabin Embarked
# 0    691        S
# 1      1        C
# 2    691        S
# 3      2        S
# 4    691        S

# %%
df.shape
# Out:
# (891, 11)

# %%
df['Embarked'].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df['Embarked'].isnull().sum()
# Out:
# 2

# %%
impute= SimpleImputer(missing_values=np.nan, strategy='most_frequent')
df['Embarked']= impute.fit_transform(df['Embarked'].values.reshape(-1,1))

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch    Ticket     Fare  \
# 0            1         0       3    1  22.0      1      0  236171.0   7.2500
# 1            2         1       1    0  38.0      1      0  236171.0  71.2833
# 2            3         1       3    0  26.0      0      0  236171.0   7.9250
# 3            4         1       1    0  35.0      1      0  113803.0  53.1000
# 4            5         0       3    1  35.0      0      0  373450.0   8.0500
#
#    Cabin Embarked
# 0    691        S
# 1      1        C
# 2    691        S
# 3      2        S
# 4    691        S

# %%
df['Embarked'].isnull().sum()
# Out:
# 0

# %%
df['Embarked'].value_counts().to_dict()
# Out:
# {'S': 646, 'C': 168, 'Q': 77}

# %%
df['Embarked']= df['Embarked'].map(df['Embarked'].value_counts().to_dict())
df.head()
# Out:
#    PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch    Ticket     Fare  \
# 0            1         0       3    1  22.0      1      0  236171.0   7.2500
# 1            2         1       1    0  38.0      1      0  236171.0  71.2833
# 2            3         1       3    0  26.0      0      0  236171.0   7.9250
# 3            4         1       1    0  35.0      1      0  113803.0  53.1000
# 4            5         0       3    1  35.0      0      0  373450.0   8.0500
#
#    Cabin  Embarked
# 0    691       646
# 1      1       168
# 2    691       646
# 3      2       646
# 4    691       646

# %%
plt.style.use('dark_background')
df['Embarked'].plot(kind='kde', color='green')
# Out:
# <Axes: ylabel='Density'>

# %%
x= df.drop(['Survived'], axis=1)
y=df['Survived']
x.head()
# Out:
#    PassengerId  Pclass  Sex   Age  SibSp  Parch    Ticket     Fare  Cabin  \
# 0            1       3    1  22.0      1      0  236171.0   7.2500    691
# 1            2       1    0  38.0      1      0  236171.0  71.2833      1
# 2            3       3    0  26.0      0      0  236171.0   7.9250    691
# 3            4       1    0  35.0      1      0  113803.0  53.1000      2
# 4            5       3    1  35.0      0      0  373450.0   8.0500    691
#
#    Embarked
# 0       646
# 1       168
# 2       646
# 3       646
# 4       646

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.2, random_state=25)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((712, 10), (179, 10), (712,), (179,))

# %%
import xgboost

# %%
xgboost.XGBClassifier().get_params()
# Out:
# {'objective': 'binary:logistic',
#  'use_label_encoder': None,
#  'base_score': None,
#  'booster': None,
#  'callbacks': None,
#  'colsample_bylevel': None,
#  'colsample_bynode': None,
#  'colsample_bytree': None,
#  'early_stopping_rounds': None,
#  'enable_categorical': False,
#  'eval_metric': None,
#  'feature_types': None,
#  'gamma': None,
#  'gpu_id': None,
#  'grow_policy': None,
#  'importance_type': None,
#  'interaction_constraints': None,
#  'learning_rate': None,
#  'max_bin': None,
#  'max_cat_threshold': None,
#  'max_cat_to_onehot': None,
#  'max_delta_step': None,
#  'max_depth': None,
#  'max_leaves': None,
#  'min_child_weight': None,
#  'missing': nan,
#  'monotone_constraints': None,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'num_parallel_tree': None,
#  'predictor': None,
#  'random_state': None,
#  'reg_alpha': None,
#  'reg_lambda': None,
#  'sampling_method': None,
#  'scale_pos_weight': None,
#  'subsample': None,
#  'tree_method': None,
# ...

# %%
model_xgboost= xgboost.XGBClassifier(learning_rate=0.1,
                                    max_depth=5,
                                    n_estimators=5000,
                                     subsample=0.5,
                                     colsample_bytree=0.5,
                                     eval_metric= 'auc',
                                     verbosity=1)

# %%
eval_set= [(x_test, y_test)]
model_xgboost.fit(x_train, y_train, early_stopping_rounds=10, eval_set=eval_set, verbose=True)
# Out:
# [0]	validation_0-auc:0.81956
# [1]	validation_0-auc:0.84195
# [2]	validation_0-auc:0.86680
# [3]	validation_0-auc:0.86994
# [4]	validation_0-auc:0.88446
# [5]	validation_0-auc:0.89086
# [6]	validation_0-auc:0.89352
# [7]	validation_0-auc:0.90285
# [8]	validation_0-auc:0.90232
# [9]	validation_0-auc:0.90172
# [10]	validation_0-auc:0.90119
# [11]	validation_0-auc:0.89805
# [12]	validation_0-auc:0.89899
# [13]	validation_0-auc:0.89632
# [14]	validation_0-auc:0.89792
# [15]	validation_0-auc:0.90112
# [16]	validation_0-auc:0.90072
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
# ...

# %%
from sklearn.metrics import roc_auc_score

# %%
y_train_predict= model_xgboost.predict_proba(x_train)[:,1]
y_test_predict= model_xgboost.predict_proba(x_test)[:,1]
roc_train= roc_auc_score(y_train, y_train_predict)
roc_test= roc_auc_score(y_test, y_test_predict)
print(f"AUC Train:{roc_train}")
print(f"AUC Test:{roc_test}")
# Out:
# AUC Train:0.9054379030580404
# AUC Test:0.9028518123667377

# %%
from sklearn.model_selection import GridSearchCV

# %%
learning_rate= [0.02, 0.05,1]
max_depth_list= [2,3,5]
n_estimators_list= [1000,2000,3000]
params_dict= {'learning_rate' : learning_rate,
             'max_depth':max_depth_list,
             'n_estimators':n_estimators_list}

num_combinations= 1
for v in params_dict.values():
    num_combinations*= len(v)
print(num_combinations)
params_dict
# Out:
# 27
# {'learning_rate': [0.02, 0.05, 1],
#  'max_depth': [2, 3, 5],
#  'n_estimators': [1000, 2000, 3000]}

# %%
def my_roc_auc_score(model, x,y):
    return roc_auc_score(y, model.predict_proba(x)[:,1])

# %%
model_xgboost_hp= GridSearchCV(estimator=xgboost.XGBClassifier(subsample=0.5,
                                                              colsample_bytree=0.25,
                                                              eval_metric='auc',
                                                              use_label_encoder=False),
param_grid= params_dict,
cv=2,
scoring= my_roc_auc_score,
return_train_score= True,
verbose= 4)
model_xgboost_hp.fit(x,y)
# Out:
# Fitting 2 folds for each of 27 candidates, totalling 54 fits
# [CV 1/2] END learning_rate=0.02, max_depth=2, n_estimators=1000;, score=(train=0.950, test=0.843) total time=   0.2s
# [CV 2/2] END learning_rate=0.02, max_depth=2, n_estimators=1000;, score=(train=0.930, test=0.881) total time=   0.2s
# [CV 1/2] END learning_rate=0.02, max_depth=2, n_estimators=2000;, score=(train=0.970, test=0.845) total time=   0.5s
# [CV 2/2] END learning_rate=0.02, max_depth=2, n_estimators=2000;, score=(train=0.960, test=0.876) total time=   0.5s
# [CV 1/2] END learning_rate=0.02, max_depth=2, n_estimators=3000;, score=(train=0.982, test=0.841) total time=   0.7s
# [CV 2/2] END learning_rate=0.02, max_depth=2, n_estimators=3000;, score=(train=0.975, test=0.871) total time=   0.7s
# [CV 1/2] END learning_rate=0.02, max_depth=3, n_estimators=1000;, score=(train=0.970, test=0.840) total time=   0.2s
# ...

# %%
df_cv_results= pd.DataFrame(model_xgboost_hp.cv_results_)
df_cv_results= df_cv_results[['rank_test_score', 'mean_train_score', 'mean_test_score', 'param_learning_rate', 'param_max_depth', 'param_n_estimators']]
df_cv_results.sort_values(by='rank_test_score', inplace=True)
df_cv_results
# Out:
#     rank_test_score  mean_train_score  mean_test_score param_learning_rate  \
# 0                 1          0.939941         0.861883                0.02
# 1                 2          0.965082         0.860897                0.02
# 9                 3          0.972334         0.859877                0.05
# 3                 4          0.965772         0.859002                0.02
# 4                 5          0.986647         0.857739                0.02
# 6                 6          0.988593         0.856544                0.02
# 2                 7          0.978425         0.855906                0.02
# 7                 8          0.997733         0.855873                0.02
# 12                9          0.991269         0.855199                0.05
# 10               10          0.991120         0.855103                0.05
# 8                11          0.999362         0.854404                0.02
# ...

# %%
df_cv_results.sort_values(by='param_n_estimators', inplace=True)

lr_d2= df_cv_results.loc[(df_cv_results['param_learning_rate']==0.05) & (df_cv_results['param_max_depth']==2)]
lr_d3= df_cv_results.loc[(df_cv_results['param_learning_rate']==0.05) & (df_cv_results['param_max_depth']==3)]
lr_d5= df_cv_results.loc[(df_cv_results['param_learning_rate']==0.05) & (df_cv_results['param_max_depth']==5)]

fig, ax= plt.subplots(figsize= (10,5))
lr_d2.plot(x='param_n_estimators', y='mean_test_score', label='Depth=2', ax=ax, color="red")
lr_d3.plot(x='param_n_estimators', y='mean_test_score', label='Depth=3', ax=ax, color="blue")
lr_d5.plot(x='param_n_estimators', y='mean_test_score', label='Depth=5', ax=ax, color="green")
plt.ylabel("Mean Validation AUC")
plt.title("Performance wrt Trees and Depth")
# Out:
# Text(0.5, 1.0, 'Performance wrt Trees and Depth')

# %%
df_cv_results.sort_values(by= 'param_learning_rate', inplace=True)
lr_t3k_d2= df_cv_results.loc[(df_cv_results['param_n_estimators']==2000)& (df_cv_results['param_max_depth']==2)]
lr_t3k_d3= df_cv_results.loc[(df_cv_results['param_n_estimators']==2000)& (df_cv_results['param_max_depth']==3)]
fig, ax= plt.subplots(figsize=(10,5))
lr_t3k_d2.plot(x='param_n_estimators', y='mean_test_score', label='Depth=2', ax=ax, color='magenta')
lr_t3k_d3.plot(x='param_n_estimators', y='mean_test_score', label='Depth=3', ax=ax, color='cyan')
plt.ylabel('Mean Validation AUC')
plt.title("Performanece wrt learning rate")
# Out:
# Text(0.5, 1.0, 'Performanece wrt learning rate')

# %%
model_xgboost_fin= xgboost.XGBClassifier(learning_rate= 0.05,
                                        max_depth=2,
                                        n_estimators=2000,
                                        subsample= 0.5,
                                        colsample_bytree= 0.25,
                                        eval_metric= 'auc',
                                        verbosity= 1,
                                        use_label_encoder= False)
eval_set= [(x_train, y_train), (x_test, y_test)]
model_xgboost_fin.fit(x_train, y_train, early_stopping_rounds=20, eval_set=eval_set, verbose=True)
# Out:
# [0]	validation_0-auc:0.64403	validation_1-auc:0.66278
# [1]	validation_0-auc:0.66065	validation_1-auc:0.65978
# [2]	validation_0-auc:0.68860	validation_1-auc:0.71962
# [3]	validation_0-auc:0.71696	validation_1-auc:0.74054
# [4]	validation_0-auc:0.72892	validation_1-auc:0.76379
# [5]	validation_0-auc:0.73774	validation_1-auc:0.77785
# [6]	validation_0-auc:0.73764	validation_1-auc:0.78771
# [7]	validation_0-auc:0.74110	validation_1-auc:0.79491
# [8]	validation_0-auc:0.74188	validation_1-auc:0.79131
# [9]	validation_0-auc:0.79230	validation_1-auc:0.83815
# [10]	validation_0-auc:0.79334	validation_1-auc:0.83715
# [11]	validation_0-auc:0.78929	validation_1-auc:0.82789
# [12]	validation_0-auc:0.79041	validation_1-auc:0.82336
# [13]	validation_0-auc:0.79046	validation_1-auc:0.82176
# [14]	validation_0-auc:0.81740	validation_1-auc:0.85281
# [15]	validation_0-auc:0.81533	validation_1-auc:0.85055
# [16]	validation_0-auc:0.83499	validation_1-auc:0.87040
# ...

# %%
y_train_predict= model_xgboost_fin.predict_proba(x_train)[:,1]
y_test_predict= model_xgboost_fin.predict_proba(x_test)[:,1]
roc_train= roc_auc_score(y_train, y_train_predict)
roc_test= roc_auc_score(y_test, y_test_predict)
print(f"AUC Train:{roc_train}")
print(f"AUC Test:{roc_test}")
# Out:
# AUC Train:0.8653380486790098
# AUC Test:0.8953891257995736

# %%
evaluation_results= model_xgboost_fin.evals_result()
train_auc_score= evaluation_results['validation_0']['auc']
test_auc_score= evaluation_results['validation_1']['auc']

plt.figure(figsize=(10,5))
plt.plot(train_auc_score, label='Train', color='yellow')
plt.plot(test_auc_score, label='Test', color='red')
plt.title('Train and Validation AUC')
plt.xlabel('Trees')
plt.ylabel('AUC')
plt.legend(loc='lower right')

# %%
df_var_imp= pd.DataFrame({'Variables': x.columns,
                         'Importance':model_xgboost_fin.feature_importances_})\
.sort_values(by='Importance', ascending=False)

df_var_imp[:10]
# Out:
#      Variables  Importance
# 2          Sex    0.508689
# 1       Pclass    0.109540
# 8        Cabin    0.086900
# 7         Fare    0.070879
# 6       Ticket    0.070785
# 3          Age    0.048666
# 4        SibSp    0.032085
# 0  PassengerId    0.028895
# 9     Embarked    0.027205
# 5        Parch    0.016356
