# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings(action='ignore')

# %%
df= pd.read_csv(r"C:\Users\DIBYOJIT\OneDrive\Documents\bank-additional\bank-additional\bank-additional.csv", delimiter=';')

# %%
df.head()
# Out:
#    age          job  marital          education default  housing     loan  \
# 0   30  blue-collar  married           basic.9y      no      yes       no
# 1   39     services   single        high.school      no       no       no
# 2   25     services  married        high.school      no      yes       no
# 3   38     services  married           basic.9y      no  unknown  unknown
# 4   47       admin.  married  university.degree      no      yes       no
#
#      contact month day_of_week  ...  campaign  pdays  previous     poutcome  \
# 0   cellular   may         fri  ...         2    999         0  nonexistent
# 1  telephone   may         fri  ...         4    999         0  nonexistent
# 2  telephone   jun         wed  ...         1    999         0  nonexistent
# 3  telephone   jun         fri  ...         3    999         0  nonexistent
# 4   cellular   nov         mon  ...         1    999         0  nonexistent
#
# ...

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'housing', 'loan',
#        'contact', 'month', 'day_of_week', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'emp.var.rate', 'cons.price.idx',
#        'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
df.shape
# Out:
# (4119, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   object
#  2   marital         4119 non-null   object
#  3   education       4119 non-null   object
#  4   default         4119 non-null   object
#  5   housing         4119 non-null   object
#  6   loan            4119 non-null   object
#  7   contact         4119 non-null   object
#  8   month           4119 non-null   object
#  9   day_of_week     4119 non-null   object
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   object
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# y                 0
# dtype: int64

# %%
df['job'].unique()
# Out:
# array(['blue-collar', 'services', 'admin.', 'entrepreneur',
#        'self-employed', 'technician', 'management', 'student', 'retired',
#        'housemaid', 'unemployed', 'unknown'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
df['job']= le.fit_transform(df['job'])

# %%
df['education'].unique()
# Out:
# array(['basic.9y', 'high.school', 'university.degree',
#        'professional.course', 'basic.6y', 'basic.4y', 'unknown',
#        'illiterate'], dtype=object)

# %%
df['education']= le.fit_transform(df['education'])
df.head()
# Out:
#    age  job  marital  education default  housing     loan    contact month  \
# 0   30    1  married          2      no      yes       no   cellular   may
# 1   39    7   single          3      no       no       no  telephone   may
# 2   25    7  married          3      no      yes       no  telephone   jun
# 3   38    7  married          2      no  unknown  unknown  telephone   jun
# 4   47    0  married          6      no      yes       no   cellular   nov
#
#   day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0         fri  ...         2    999         0  nonexistent         -1.8
# 1         fri  ...         4    999         0  nonexistent          1.1
# 2         wed  ...         1    999         0  nonexistent          1.4
# 3         fri  ...         3    999         0  nonexistent          1.4
# 4         mon  ...         1    999         0  nonexistent         -0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df['marital'].unique()
# Out:
# array(['married', 'single', 'divorced', 'unknown'], dtype=object)

# %%
df['marital']= df['marital'].map({'married':2, 'single':1,'divorced':0,'unknown':3})
df.head()
# Out:
#    age  job  marital  education default  housing     loan    contact month  \
# 0   30    1        2          2      no      yes       no   cellular   may
# 1   39    7        1          3      no       no       no  telephone   may
# 2   25    7        2          3      no      yes       no  telephone   jun
# 3   38    7        2          2      no  unknown  unknown  telephone   jun
# 4   47    0        2          6      no      yes       no   cellular   nov
#
#   day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0         fri  ...         2    999         0  nonexistent         -1.8
# 1         fri  ...         4    999         0  nonexistent          1.1
# 2         wed  ...         1    999         0  nonexistent          1.4
# 3         fri  ...         3    999         0  nonexistent          1.4
# 4         mon  ...         1    999         0  nonexistent         -0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df['default'].unique()
# Out:
# array(['no', 'unknown', 'yes'], dtype=object)

# %%
df['default']= df['default'].map({'yes':1, 'no':0, 'unknown':2})
df.head()
# Out:
#    age  job  marital  education  default  housing     loan    contact month  \
# 0   30    1        2          2        0      yes       no   cellular   may
# 1   39    7        1          3        0       no       no  telephone   may
# 2   25    7        2          3        0      yes       no  telephone   jun
# 3   38    7        2          2        0  unknown  unknown  telephone   jun
# 4   47    0        2          6        0      yes       no   cellular   nov
#
#   day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0         fri  ...         2    999         0  nonexistent         -1.8
# 1         fri  ...         4    999         0  nonexistent          1.1
# 2         wed  ...         1    999         0  nonexistent          1.4
# 3         fri  ...         3    999         0  nonexistent          1.4
# 4         mon  ...         1    999         0  nonexistent         -0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df['housing'].unique().
# Out:
# array(['yes', 'no', 'unknown'], dtype=object)

# %%
df['housing']= df['housing'].map({'yes':1, 'no':0,'unknown':2})
df.head()
# Out:
#    age  job  marital  education  default  housing     loan    contact month  \
# 0   30    1        2          2        0        1       no   cellular   may
# 1   39    7        1          3        0        0       no  telephone   may
# 2   25    7        2          3        0        1       no  telephone   jun
# 3   38    7        2          2        0        2  unknown  telephone   jun
# 4   47    0        2          6        0        1       no   cellular   nov
#
#   day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0         fri  ...         2    999         0  nonexistent         -1.8
# 1         fri  ...         4    999         0  nonexistent          1.1
# 2         wed  ...         1    999         0  nonexistent          1.4
# 3         fri  ...         3    999         0  nonexistent          1.4
# 4         mon  ...         1    999         0  nonexistent         -0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df['loan'].unique()
# Out:
# array(['no', 'unknown', 'yes'], dtype=object)

# %%
df['loan']= df['loan'].map({'yes':1, 'no':0,'unknown':2})
df.head()
# Out:
#    age  job  marital  education  default  housing  loan    contact month  \
# 0   30    1        2          2        0        1     0   cellular   may
# 1   39    7        1          3        0        0     0  telephone   may
# 2   25    7        2          3        0        1     0  telephone   jun
# 3   38    7        2          2        0        2     2  telephone   jun
# 4   47    0        2          6        0        1     0   cellular   nov
#
#   day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0         fri  ...         2    999         0  nonexistent         -1.8
# 1         fri  ...         4    999         0  nonexistent          1.1
# 2         wed  ...         1    999         0  nonexistent          1.4
# 3         fri  ...         3    999         0  nonexistent          1.4
# 4         mon  ...         1    999         0  nonexistent         -0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df['contact'].unique()
# Out:
# array(['cellular', 'telephone'], dtype=object)

# %%
df['contact']= df['contact'].map({'cellular':1, 'telephone':0})
df.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact month  \
# 0   30    1        2          2        0        1     0        1   may
# 1   39    7        1          3        0        0     0        0   may
# 2   25    7        2          3        0        1     0        0   jun
# 3   38    7        2          2        0        2     2        0   jun
# 4   47    0        2          6        0        1     0        1   nov
#
#   day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0         fri  ...         2    999         0  nonexistent         -1.8
# 1         fri  ...         4    999         0  nonexistent          1.1
# 2         wed  ...         1    999         0  nonexistent          1.4
# 3         fri  ...         3    999         0  nonexistent          1.4
# 4         mon  ...         1    999         0  nonexistent         -0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df['month'].unique()
# Out:
# array(['may', 'jun', 'nov', 'sep', 'jul', 'aug', 'mar', 'oct', 'apr',
#        'dec'], dtype=object)

# %%
df['month']= df['month'].map({'mar':3, 'apr':4, 'may':5, 'jun':6, 'jul':7,'aug':8, 'sep':9, 'oct':10, 'nov':11, 'dec':12})
df.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   30    1        2          2        0        1     0        1      5
# 1   39    7        1          3        0        0     0        0      5
# 2   25    7        2          3        0        1     0        0      6
# 3   38    7        2          2        0        2     2        0      6
# 4   47    0        2          6        0        1     0        1     11
#
#   day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0         fri  ...         2    999         0  nonexistent         -1.8
# 1         fri  ...         4    999         0  nonexistent          1.1
# 2         wed  ...         1    999         0  nonexistent          1.4
# 3         fri  ...         3    999         0  nonexistent          1.4
# 4         mon  ...         1    999         0  nonexistent         -0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df['day_of_week'].unique()
# Out:
# array(['fri', 'wed', 'mon', 'thu', 'tue'], dtype=object)

# %%
df['day_of_week']= df['day_of_week'].map({'mon':1, 'tue':2,'wed':3, 'thu':4, 'fri':5})
df.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   30    1        2          2        0        1     0        1      5
# 1   39    7        1          3        0        0     0        0      5
# 2   25    7        2          3        0        1     0        0      6
# 3   38    7        2          2        0        2     2        0      6
# 4   47    0        2          6        0        1     0        1     11
#
#    day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0            5  ...         2    999         0  nonexistent         -1.8
# 1            5  ...         4    999         0  nonexistent          1.1
# 2            3  ...         1    999         0  nonexistent          1.4
# 3            5  ...         3    999         0  nonexistent          1.4
# 4            1  ...         1    999         0  nonexistent         -0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df['poutcome'].unique()
# Out:
# array(['nonexistent', 'failure', 'success'], dtype=object)

# %%
df['poutcome']= df['poutcome'].map({'failure':0, 'nonexistent':1, 'success':2})
df.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   30    1        2          2        0        1     0        1      5
# 1   39    7        1          3        0        0     0        0      5
# 2   25    7        2          3        0        1     0        0      6
# 3   38    7        2          2        0        2     2        0      6
# 4   47    0        2          6        0        1     0        1     11
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            5  ...         2    999         0         1          -1.8
# 1            5  ...         4    999         0         1           1.1
# 2            3  ...         1    999         0         1           1.4
# 3            5  ...         3    999         0         1           1.4
# 4            1  ...         1    999         0         1          -0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df['emp.var.rate']= np.abs(df['emp.var.rate'])
df.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   30    1        2          2        0        1     0        1      5
# 1   39    7        1          3        0        0     0        0      5
# 2   25    7        2          3        0        1     0        0      6
# 3   38    7        2          2        0        2     2        0      6
# 4   47    0        2          6        0        1     0        1     11
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            5  ...         2    999         0         1           1.8
# 1            5  ...         4    999         0         1           1.1
# 2            3  ...         1    999         0         1           1.4
# 3            5  ...         3    999         0         1           1.4
# 4            1  ...         1    999         0         1           0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df['cons.conf.idx']= np.abs(df['cons.conf.idx'])
df.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   30    1        2          2        0        1     0        1      5
# 1   39    7        1          3        0        0     0        0      5
# 2   25    7        2          3        0        1     0        0      6
# 3   38    7        2          2        0        2     2        0      6
# 4   47    0        2          6        0        1     0        1     11
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            5  ...         2    999         0         1           1.8
# 1            5  ...         4    999         0         1           1.1
# 2            3  ...         1    999         0         1           1.4
# 3            5  ...         3    999         0         1           1.4
# 4            1  ...         1    999         0         1           0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed   y
# ...

# %%
df['y'].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
df['y']= df['y'].map({'no':0, 'yes':1})
df.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   30    1        2          2        0        1     0        1      5
# 1   39    7        1          3        0        0     0        0      5
# 2   25    7        2          3        0        1     0        0      6
# 3   38    7        2          2        0        2     2        0      6
# 4   47    0        2          6        0        1     0        1     11
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            5  ...         2    999         0         1           1.8
# 1            5  ...         4    999         0         1           1.1
# 2            3  ...         1    999         0         1           1.4
# 3            5  ...         3    999         0         1           1.4
# 4            1  ...         1    999         0         1           0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4119 entries, 0 to 4118
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             4119 non-null   int64
#  1   job             4119 non-null   int32
#  2   marital         4119 non-null   int64
#  3   education       4119 non-null   int32
#  4   default         4119 non-null   int64
#  5   housing         4119 non-null   int64
#  6   loan            4119 non-null   int64
#  7   contact         4119 non-null   int64
#  8   month           4119 non-null   int64
#  9   day_of_week     4119 non-null   int64
#  10  duration        4119 non-null   int64
#  11  campaign        4119 non-null   int64
#  12  pdays           4119 non-null   int64
#  13  previous        4119 non-null   int64
#  14  poutcome        4119 non-null   int64
#  15  emp.var.rate    4119 non-null   float64
#  16  cons.price.idx  4119 non-null   float64
# ...

# %%
plt.style.use('dark_background')
df['age'].plot(kind='kde', color='red')
# Out:
# <Axes: ylabel='Density'>

# %%
# !pip install xgboost
# Out:
# ...
#   Obtaining dependency information for xgboost from https://files.pythonhosted.org/packages/75/dd/9afe0d9d0f61a5384c3932626a022e38c396a5d88e6f5345ad2f7b576747/xgboost-1.7.6-py3-none-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/70.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/70.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/70.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/70.9 MB 245.8 kB/s eta 0:04:49
#    ---------------------------------------- 0.0/70.9 MB 245.8 kB/s eta 0:04:49
#    ---------------------------------------- 0.1/70.9 MB 403.5 kB/s eta 0:02:56
#    ---------------------------------------- 0.2/70.9 MB 541.0 kB/s eta 0:02:11
#    ---------------------------------------- 0.3/70.9 MB 951.8 kB/s eta 0:01:15
#    ---------------------------------------- 0.3/70.9 MB 999.0 kB/s eta 0:01:11
#     --------------------------------------- 0.9/70.9 MB 2.4 MB/s eta 0:00:30
# ...

# %%
from xgboost import XGBClassifier

# %%
df.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   30    1        2          2        0        1     0        1      5
# 1   39    7        1          3        0        0     0        0      5
# 2   25    7        2          3        0        1     0        0      6
# 3   38    7        2          2        0        2     2        0      6
# 4   47    0        2          6        0        1     0        1     11
#
#    day_of_week  ...  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            5  ...         2    999         0         1           1.8
# 1            5  ...         4    999         0         1           1.1
# 2            3  ...         1    999         0         1           1.4
# 3            5  ...         3    999         0         1           1.4
# 4            1  ...         1    999         0         1           0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed  y
# ...

# %%
x= df.drop(['y'], axis=1)
y= df['y']
x.head()
# Out:
#    age  job  marital  education  default  housing  loan  contact  month  \
# 0   30    1        2          2        0        1     0        1      5
# 1   39    7        1          3        0        0     0        0      5
# 2   25    7        2          3        0        1     0        0      6
# 3   38    7        2          2        0        2     2        0      6
# 4   47    0        2          6        0        1     0        1     11
#
#    day_of_week  duration  campaign  pdays  previous  poutcome  emp.var.rate  \
# 0            5       487         2    999         0         1           1.8
# 1            5       346         4    999         0         1           1.1
# 2            3       227         1    999         0         1           1.4
# 3            5        17         3    999         0         1           1.4
# 4            1        58         1    999         0         1           0.1
#
#    cons.price.idx  cons.conf.idx  euribor3m  nr.employed
# ...

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.2, random_state=20)

# %%
y_train
# Out:
# 136     0
# 1659    0
# 3022    0
# 664     1
# 1128    0
#        ..
# 3234    0
# 1607    0
# 3915    0
# 1428    0
# 2522    0
# Name: y, Length: 3295, dtype: int64

# %%
x_train.dtypes
# Out:
# age                 int64
# job                 int32
# marital             int64
# education           int32
# default             int64
# housing             int64
# loan                int64
# contact             int64
# month               int64
# day_of_week         int64
# duration            int64
# campaign            int64
# pdays               int64
# previous            int64
# poutcome            int64
# emp.var.rate      float64
# cons.price.idx    float64
# cons.conf.idx     float64
# euribor3m         float64
# nr.employed       float64
# dtype: object

# %%
clf= XGBClassifier()
clf.fit(x_train ,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
y_pred= clf.predict(x_test)
y_pred[:5]
# Out:
# array([0, 0, 0, 0, 0])

# %%
y_test[:5]
# Out:
# 1618    0
# 2270    0
# 1451    0
# 1709    0
# 3432    0
# Name: y, dtype: int64

# %%
clf.score(x_test, y_test)
# Out:
# 0.9199029126213593

# %%
clf.predict_proba(x_test[:2])
# Out:
# array([[0.9983093 , 0.00169067],
#        [0.56677794, 0.43322203]], dtype=float32)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_pred, y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.96       761
#            1       0.48      0.67      0.56        63
#
#     accuracy                           0.92       824
#    macro avg       0.73      0.80      0.76       824
# weighted avg       0.93      0.92      0.93       824
